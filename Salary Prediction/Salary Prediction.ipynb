# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv("Salary Prediction.csv")
df.head(15)
# Out:
#     Unnamed: 0                          Job Title  \
# 0            0                     Data Scientist
# 1            1          Healthcare Data Scientist
# 2            2                     Data Scientist
# 3            3                     Data Scientist
# 4            4                     Data Scientist
# 5            5                     Data Scientist
# 6            6                     Data Scientist
# 7            7                     Data Scientist
# 8            8                 Research Scientist
# 9            9                     Data Scientist
# 10          10                     Data Scientist
# 11          11                     Data Scientist
# 12          12  Staff Data Scientist - Technology
# 13          13                       Data Analyst
# 14          14                     Data Scientist
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# 5    $71K-$119K (Glassdoor est.)
# 6     $54K-$93K (Glassdoor est.)
# 7    $86K-$142K (Glassdoor est.)
# 8     $38K-$84K (Glassdoor est.)
# 9   $120K-$160K (Glassdoor est.)
# 10  $126K-$201K (Glassdoor est.)
# 11   $64K-$106K (Glassdoor est.)
# 12  $106K-$172K (Glassdoor est.)
# 13    $46K-$85K (Glassdoor est.)
# 14   $83K-$144K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1   What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2   KnowBe4, Inc. is a high growth information sec...     4.8
# 3   *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4   Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5   CyrusOne is seeking a talented Data Scientist ...     3.4
# 6   Job Description\n\n**Please only local candida...     4.1
# 7   Advanced Analytics – Lead Data Scientist\nOver...     3.8
# 8   SUMMARY\n\nThe Research Scientist I will be ta...     3.3
# 9   isn’t your usual company. Our work is powered ...     4.6
# 10  At Wish, our Data Science & Engineering team i...     3.5
# 11  Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 12  Position Summary...\nDrives the execution of m...     3.2
# 13  Are you an experienced Data Analyst, skilled a...     4.1
# 14  Job Description\n\n\nTakeda is looking for a D...     3.7
#
#                                   Company Name         Location  \
# 0                       Tecolote Research\n3.8  Albuquerque, NM
# 1   University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                 KnowBe4\n4.8   Clearwater, FL
# 3                                    PNNL\n3.8     Richland, WA
# 4                      Affinity Solutions\n2.9     New York, NY
# 5                                CyrusOne\n3.4       Dallas, TX
# 6                      ClearOne Advantage\n4.1    Baltimore, MD
# 7                              Logic20/20\n3.8     San Jose, CA
# 8               Rochester Regional Health\n3.3    Rochester, NY
# 9                                <intent>\n4.6     New York, NY
# 10                                   Wish\n3.5     San Jose, CA
# 11                                ManTech\n4.1    Chantilly, VA
# 12                                Walmart\n3.2        Plano, TX
# 13                                 Yesler\n4.1      Seattle, WA
# 14                 Takeda Pharmaceuticals\n3.7    Cambridge, MA
#
#          Headquarters                     Size  Founded  ...  age python_yn  \
# 0          Goleta, CA    501 to 1000 employees     1973  ...   47         1
# 1       Baltimore, MD         10000+ employees     1984  ...   36         1
# 2      Clearwater, FL    501 to 1000 employees     2010  ...   10         1
# 3        Richland, WA   1001 to 5000 employees     1965  ...   55         1
# 4        New York, NY      51 to 200 employees     1998  ...   22         1
# 5          Dallas, TX     201 to 500 employees     2000  ...   20         1
# 6       Baltimore, MD    501 to 1000 employees     2008  ...   12         0
# 7         Seattle, WA     201 to 500 employees     2005  ...   15         1
# 8       Rochester, NY         10000+ employees     2014  ...    6         0
# 9        New York, NY      51 to 200 employees     2009  ...   11         1
# 10  San Francisco, CA    501 to 1000 employees     2011  ...    9         1
# 11        Herndon, VA  5001 to 10000 employees     1968  ...   52         0
# 12    Bentonville, AR         10000+ employees     1962  ...   58         0
# 13        Seattle, WA     201 to 500 employees     2012  ...    8         1
# 14       OSAKA, Japan         10000+ employees     1781  ...  239         1
#
#    R_yn spark aws  excel        job_simp  seniority  desc_len  num_comp
# 0     0     0   0      1  data scientist         na      2536         0
# 1     0     0   0      0  data scientist         na      4783         0
# 2     0     1   0      1  data scientist         na      3461         0
# 3     0     0   0      0  data scientist         na      3883         3
# 4     0     0   0      1  data scientist         na      2728         3
# 5     0     0   1      1  data scientist         na      3747         3
# 6     0     0   0      1  data scientist         na      1786         0
# 7     0     1   1      1  data scientist         na      3804         0
# 8     0     0   0      0              na         na      1538         0
# 9     0     1   0      0  data scientist         na      4574         2
# 10    0     0   0      0  data scientist         na      2757         0
# 11    0     0   0      0  data scientist         na      3490         0
# 12    0     0   0      0  data scientist         na      3934         3
# 13    0     1   1      1         analyst         na      4897         0
# 14    0     1   0      0  data scientist         na      3731         3
#
# [15 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         742 non-null    int64
#  1   Job Title          742 non-null    object
#  2   Salary Estimate    742 non-null    object
#  3   Job Description    742 non-null    object
#  4   Rating             742 non-null    float64
#  5   Company Name       742 non-null    object
#  6   Location           742 non-null    object
#  7   Headquarters       742 non-null    object
#  8   Size               742 non-null    object
#  9   Founded            742 non-null    int64
#  10  Type of ownership  742 non-null    object
#  11  Industry           742 non-null    object
#  12  Sector             742 non-null    object
#  13  Revenue            742 non-null    object
#  14  Competitors        742 non-null    object
#  15  hourly             742 non-null    int64
#  16  employer_provided  742 non-null    int64
#  17  min_salary         742 non-null    int64
#  18  max_salary         742 non-null    int64
#  19  avg_salary         742 non-null    float64
#  20  company_txt        742 non-null    object
#  21  job_state          742 non-null    object
#  22  same_state         742 non-null    int64
#  23  age                742 non-null    int64
#  24  python_yn          742 non-null    int64
#  25  R_yn               742 non-null    int64
#  26  spark              742 non-null    int64
#  27  aws                742 non-null    int64
#  28  excel              742 non-null    int64
#  29  job_simp           742 non-null    object
#  30  seniority          742 non-null    object
#  31  desc_len           742 non-null    int64
#  32  num_comp           742 non-null    int64
# dtypes: float64(2), int64(15), object(16)
# memory usage: 191.4+ KB
